# %% [markdown]
# ### 实现梯度下降
# ##### 基于pytorch

# %% [markdown]
# #### 1.定义函数

# %%
def f(x,y):
    return x**2 + y**2

# %% [markdown]
# #### 2.定义输入

# %%
import torch
x = torch.tensor([1.1], requires_grad=True)
y = torch.tensor([2.1], requires_grad=True)
n = 100 # 迭代次数
lr = 0.1 # 学习率

# %% [markdown]
# ### 3.梯度下降

# %%
def gradient_descent(x, y, lr, n):
    for i in range(n):
        z = f(x, y) # 计算函数值
        z.backward() # 计算z关于x和y的梯度

        x.data -= lr * x.grad.data # 更新x
        y.data -= lr * y.grad.data # 更新y
        x.grad.data.zero_() # 清零x的梯度
        y.grad.data.zero_() # 清零y的梯度
        print(f'After {i+1} iteration:'
            f'x = {x.item():.4f} '
            f'y = {y.item():.4f} '
            f'f(x, y) = {z.item():.4f}')
    return x, y

# %%
gradient_descent(x, y, lr, n)
# Out:
# After 1 iteration:x = 0.8800 y = 1.6800 f(x, y) = 5.6200
# After 2 iteration:x = 0.7040 y = 1.3440 f(x, y) = 3.5968
# After 3 iteration:x = 0.5632 y = 1.0752 f(x, y) = 2.3020
# After 4 iteration:x = 0.4506 y = 0.8602 f(x, y) = 1.4732
# After 5 iteration:x = 0.3604 y = 0.6881 f(x, y) = 0.9429
# After 6 iteration:x = 0.2884 y = 0.5505 f(x, y) = 0.6034
# After 7 iteration:x = 0.2307 y = 0.4404 f(x, y) = 0.3862
# After 8 iteration:x = 0.1845 y = 0.3523 f(x, y) = 0.2472
# After 9 iteration:x = 0.1476 y = 0.2819 f(x, y) = 0.1582
# After 10 iteration:x = 0.1181 y = 0.2255 f(x, y) = 0.1012
# After 11 iteration:x = 0.0945 y = 0.1804 f(x, y) = 0.0648
# After 12 iteration:x = 0.0756 y = 0.1443 f(x, y) = 0.0415
# After 13 iteration:x = 0.0605 y = 0.1154 f(x, y) = 0.0265
# After 14 iteration:x = 0.0484 y = 0.0924 f(x, y) = 0.0170
# After 15 iteration:x = 0.0387 y = 0.0739 f(x, y) = 0.0109
# After 16 iteration:x = 0.0310 y = 0.0591 f(x, y) = 0.0070
# After 17 iteration:x = 0.0248 y = 0.0473 f(x, y) = 0.0045
# After 18 iteration:x = 0.0198 y = 0.0378 f(x, y) = 0.0028
# After 19 iteration:x = 0.0159 y = 0.0303 f(x, y) = 0.0018
# After 20 iteration:x = 0.0127 y = 0.0242 f(x, y) = 0.0012
# After 21 iteration:x = 0.0101 y = 0.0194 f(x, y) = 0.0007
# After 22 iteration:x = 0.0081 y = 0.0155 f(x, y) = 0.0005
# After 23 iteration:x = 0.0065 y = 0.0124 f(x, y) = 0.0003
# After 24 iteration:x = 0.0052 y = 0.0099 f(x, y) = 0.0002
# After 25 iteration:x = 0.0042 y = 0.0079 f(x, y) = 0.0001
# After 26 iteration:x = 0.0033 y = 0.0063 f(x, y) = 0.0001
# After 27 iteration:x = 0.0027 y = 0.0051 f(x, y) = 0.0001
# After 28 iteration:x = 0.0021 y = 0.0041 f(x, y) = 0.0000
# After 29 iteration:x = 0.0017 y = 0.0032 f(x, y) = 0.0000
# After 30 iteration:x = 0.0014 y = 0.0026 f(x, y) = 0.0000
# After 31 iteration:x = 0.0011 y = 0.0021 f(x, y) = 0.0000
# After 32 iteration:x = 0.0009 y = 0.0017 f(x, y) = 0.0000
# After 33 iteration:x = 0.0007 y = 0.0013 f(x, y) = 0.0000
# After 34 iteration:x = 0.0006 y = 0.0011 f(x, y) = 0.0000
# After 35 iteration:x = 0.0004 y = 0.0009 f(x, y) = 0.0000
# After 36 iteration:x = 0.0004 y = 0.0007 f(x, y) = 0.0000
# After 37 iteration:x = 0.0003 y = 0.0005 f(x, y) = 0.0000
# After 38 iteration:x = 0.0002 y = 0.0004 f(x, y) = 0.0000
# After 39 iteration:x = 0.0002 y = 0.0003 f(x, y) = 0.0000
# After 40 iteration:x = 0.0001 y = 0.0003 f(x, y) = 0.0000
# After 41 iteration:x = 0.0001 y = 0.0002 f(x, y) = 0.0000
# After 42 iteration:x = 0.0001 y = 0.0002 f(x, y) = 0.0000
# After 43 iteration:x = 0.0001 y = 0.0001 f(x, y) = 0.0000
# After 44 iteration:x = 0.0001 y = 0.0001 f(x, y) = 0.0000
# After 45 iteration:x = 0.0000 y = 0.0001 f(x, y) = 0.0000
# After 46 iteration:x = 0.0000 y = 0.0001 f(x, y) = 0.0000
# After 47 iteration:x = 0.0000 y = 0.0001 f(x, y) = 0.0000
# After 48 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 49 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 50 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 51 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 52 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 53 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 54 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 55 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 56 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 57 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 58 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 59 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 60 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 61 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 62 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 63 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 64 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 65 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 66 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 67 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 68 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 69 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 70 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 71 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 72 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 73 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 74 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 75 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 76 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 77 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 78 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 79 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 80 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 81 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 82 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 83 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 84 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 85 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 86 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 87 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 88 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 89 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 90 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 91 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 92 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 93 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 94 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 95 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 96 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 97 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 98 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 99 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# After 100 iteration:x = 0.0000 y = 0.0000 f(x, y) = 0.0000
# (tensor([2.2407e-10], requires_grad=True),
#  tensor([4.2778e-10], requires_grad=True))

# %% [markdown]
# ### 可视化

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# --- 设置Matplotlib支持中文 ---
# macOS使用 'Arial Unicode MS', Windows使用 'SimHei'
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei'] 
plt.rcParams['axes.unicode_minus'] = False # 解决负号显示为方块的问题
# ---------------------------

# 重新初始化参数，记录优化轨迹
x_opt = torch.tensor([1.1], requires_grad=True)
y_opt = torch.tensor([2.1], requires_grad=True)

# 记录优化过程中的所有点
trajectory_x = [x_opt.item()]
trajectory_y = [y_opt.item()]

for i in range(n):
    z = f(x_opt, y_opt)
    z.backward()
    
    x_opt.data -= lr * x_opt.grad.data
    y_opt.data -= lr * y_opt.grad.data
    x_opt.grad.zero_()
    y_opt.grad.zero_()
    
    trajectory_x.append(x_opt.item())
    trajectory_y.append(y_opt.item())

# 创建网格用于绘制函数图像
x_range = np.linspace(-0.5, 2.5, 100)
y_range = np.linspace(-0.5, 2.5, 100)
X, Y = np.meshgrid(x_range, y_range)
Z = X**2 + Y**2

# 创建图表：等高线图 + 优化轨迹
fig, ax = plt.subplots(figsize=(10, 8))

# 绘制等高线
contour = ax.contour(X, Y, Z, levels=20, cmap='viridis', alpha=0.6)
ax.clabel(contour, inline=True, fontsize=8)

# 绘制优化轨迹
ax.plot(trajectory_x, trajectory_y, 'r-', linewidth=2, label='优化轨迹', alpha=0.7)
ax.plot(trajectory_x, trajectory_y, 'ro', markersize=4, alpha=0.6)

# 标记起始点和终点
ax.plot(trajectory_x[0], trajectory_y[0], 'go', markersize=12, label='起始点', zorder=5)
ax.plot(trajectory_x[-1], trajectory_y[-1], 'bs', markersize=12, label='终点', zorder=5)

# 标记最优点
ax.plot(0, 0, 'k*', markersize=20, label='最优点 (0,0)', zorder=5)

ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.set_title('梯度下降优化过程 - 等高线图', fontsize=13, fontweight='bold')
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')

plt.tight_layout()
plt.show()

# 创建3D表面图
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111, projection='3d')

# 绘制3D表面
surf = ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.6, edgecolor='none')

# 计算优化轨迹上的Z值
trajectory_z = [x_opt_val**2 + y_opt_val**2 for x_opt_val, y_opt_val in zip(trajectory_x, trajectory_y)]

# 绘制优化轨迹在3D空间中的路径
ax.plot(trajectory_x, trajectory_y, trajectory_z, 'r-', linewidth=3, label='优化轨迹')
ax.plot(trajectory_x, trajectory_y, trajectory_z, 'ro', markersize=3, alpha=0.5)

# 标记起始点和终点
ax.plot([trajectory_x[0]], [trajectory_y[0]], [trajectory_z[0]], 'go', markersize=12, label='起始点')
ax.plot([trajectory_x[-1]], [trajectory_y[-1]], [trajectory_z[-1]], 'bs', markersize=12, label='终点')

ax.set_xlabel('x', fontsize=11)
ax.set_ylabel('y', fontsize=11)
ax.set_zlabel('f(x,y)', fontsize=11)
ax.set_title('梯度下降优化过程 - 3D表面图', fontsize=13, fontweight='bold')
ax.legend(fontsize=11)

fig.colorbar(surf, ax=ax, label='函数值')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 26799 (\N{CJK UNIFIED IDEOGRAPH-68AF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 19979 (\N{CJK UNIFIED IDEOGRAPH-4E0B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 38477 (\N{CJK UNIFIED IDEOGRAPH-964D}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 20248 (\N{CJK UNIFIED IDEOGRAPH-4F18}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 36807 (\N{CJK UNIFIED IDEOGRAPH-8FC7}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 36712 (\N{CJK UNIFIED IDEOGRAPH-8F68}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 36857 (\N{CJK UNIFIED IDEOGRAPH-8FF9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 36215 (\N{CJK UNIFIED IDEOGRAPH-8D77}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 22987 (\N{CJK UNIFIED IDEOGRAPH-59CB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 32456 (\N{CJK UNIFIED IDEOGRAPH-7EC8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:56: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 26799 (\N{CJK UNIFIED IDEOGRAPH-68AF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 19979 (\N{CJK UNIFIED IDEOGRAPH-4E0B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 38477 (\N{CJK UNIFIED IDEOGRAPH-964D}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 20248 (\N{CJK UNIFIED IDEOGRAPH-4F18}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 36807 (\N{CJK UNIFIED IDEOGRAPH-8FC7}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 34920 (\N{CJK UNIFIED IDEOGRAPH-8868}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 38754 (\N{CJK UNIFIED IDEOGRAPH-9762}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 36712 (\N{CJK UNIFIED IDEOGRAPH-8F68}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 36857 (\N{CJK UNIFIED IDEOGRAPH-8FF9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 36215 (\N{CJK UNIFIED IDEOGRAPH-8D77}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 22987 (\N{CJK UNIFIED IDEOGRAPH-59CB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 32456 (\N{CJK UNIFIED IDEOGRAPH-7EC8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 20989 (\N{CJK UNIFIED IDEOGRAPH-51FD}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/4p/q2krs31n1f7_2g493jglfh9r0000gn/T/ipykernel_98640/3997690465.py:84: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
